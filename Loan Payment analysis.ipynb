# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('C:/Users/amose/OneDrive/Desktop/python programming for finance/Loan payments data.csv')
df
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Loan_ID         500 non-null    object
#  1   loan_status     500 non-null    object
#  2   Principal       500 non-null    int64
#  3   terms           500 non-null    int64
#  4   effective_date  500 non-null    object
#  5   due_date        500 non-null    object
#  6   paid_off_time   400 non-null    object
#  7   past_due_days   200 non-null    float64
#  8   age             500 non-null    int64
#  9   education       500 non-null    object
#  10  Gender          500 non-null    object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 43.1+ KB

# %%
mean=df.past_due_days.mean()
df.past_due_days.fillna(mean, inplace=True)
df
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# ...

# %%
print(df.loan_status.unique())

plt.figure(figsize=(12,7))
sns.set_theme(style="darkgrid")
sns.countplot(df.loan_status,palette="Set2")
#ax = sns.countplot(df.loan_status, data=df,facecolor=(0, 0, 0, 0),linewidth=5,edgecolor=sns.color_palette("dark", 3))
# Out:
# ['PAIDOFF' 'COLLECTION' 'COLLECTION_PAIDOFF']
# c:\users\amose\appdata\local\programs\python\python39\scripts\opencv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='loan_status', ylabel='count'>

# %%
print(df.loan_status.unique())

plt.figure(figsize=(12,7))
sns.set_theme(style="darkgrid")
sns.countplot(df.terms,palette="Set2")

plt.figure(figsize=(10,7))
sns.set_theme(style="darkgrid")
sns.countplot(df.terms,hue=df.loan_status,palette="Set2")
plt.legend(loc='best')
# Out:
# ['PAIDOFF' 'COLLECTION' 'COLLECTION_PAIDOFF']
# c:\users\amose\appdata\local\programs\python\python39\scripts\opencv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\amose\appdata\local\programs\python\python39\scripts\opencv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
effective_date = df.groupby(['effective_date'])['loan_status'].value_counts()
effective_date
# Out:
# effective_date  loan_status
# 9/10/2016       COLLECTION             20
#                 PAIDOFF                19
#                 COLLECTION_PAIDOFF      7
# 9/11/2016       PAIDOFF               119
#                 COLLECTION             71
#                 COLLECTION_PAIDOFF     41
# 9/12/2016       PAIDOFF                97
#                 COLLECTION_PAIDOFF     47
#                 COLLECTION              4
# 9/13/2016       PAIDOFF                23
# 9/14/2016       PAIDOFF                33
# 9/8/2016        PAIDOFF                 4
# 9/9/2016        COLLECTION              5
#                 COLLECTION_PAIDOFF      5
#                 PAIDOFF                 5
# Name: loan_status, dtype: int64

# %%
plt.figure(figsize=(10,4))
sns.set_theme(style="darkgrid")
sns.countplot(df.effective_date, hue= df.loan_status,palette="Set1")
plt.title('effective Date')

plt.figure(figsize=(20,14))
sns.set_theme(style="darkgrid")
sns.countplot(df.due_date, hue= df.loan_status,palette="Set1")
plt.title('Due Date')
# Out:
# c:\users\amose\appdata\local\programs\python\python39\scripts\opencv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\amose\appdata\local\programs\python\python39\scripts\opencv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Due Date')

# %%
plt.figure(figsize=(10,4))
sns.set_theme(style="darkgrid")
sns.histplot(x=df.age, y=df.education, hue= df.loan_status)
#plt.title('Loan Date')
# Out:
# <AxesSubplot:xlabel='age', ylabel='education'>

# %%
Education = df['education'].value_counts()
Education
# Out:
# college                 220
# High School or Below    209
# Bechalor                 67
# Master or Above           4
# Name: education, dtype: int64

# %%
plt.figure(figsize=(10,4))
sns.set_theme(style="darkgrid")
sns.countplot(df.education, hue= df.loan_status)
plt.title('education vs loan status')

print('most of the loan takers are High schoolor below and college')
# Out:
# c:\users\amose\appdata\local\programs\python\python39\scripts\opencv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# most of the loan takers are High schoolor below and college

# %%
Gender = df['Gender'].value_counts()
Gender
# Out:
# male      423
# female     77
# Name: Gender, dtype: int64

# %%
plt.figure(figsize=(10,4))
sns.set_theme(style="darkgrid")
sns.countplot(df.Gender, hue= df.loan_status, palette='rocket')
plt.title('gender vs loan status')
# Out:
# c:\users\amose\appdata\local\programs\python\python39\scripts\opencv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'gender vs loan status')

# %%
Age = df['age'].value_counts()
Age
# Out:
# 26    46
# 29    42
# 27    38
# 30    37
# 28    32
# 33    30
# 35    26
# 34    25
# 24    23
# 31    22
# 25    20
# 32    20
# 38    19
# 37    19
# 36    14
# 23    10
# 39    10
# 22     8
# 40     8
# 21     7
# 41     5
# 43     5
# 45     5
# 46     5
# 50     4
# 20     4
# 42     4
# 44     4
# 47     3
# 19     2
# 18     1
# 49     1
# 51     1
# Name: age, dtype: int64

# %%
plt.figure(figsize=(20,14))
sns.set_theme(style="darkgrid")
sns.countplot(df.age, hue= df.loan_status, palette='rocket')
plt.title('age vs loan status')

print('The majority of sammple observation that took the loan are age range between 23 and 39')
# Out:
# c:\users\amose\appdata\local\programs\python\python39\scripts\opencv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# The majority of sammple observation that took the loan are age range between 23 and 39

# %%
Gender = df['Principal'].value_counts()
Gender
# Out:
# 1000    377
# 800     111
# 300       6
# 500       3
# 900       2
# 700       1
# Name: Principal, dtype: int64

# %%
plt.figure(figsize=(20,14))
sns.set_theme(style="darkgrid")
sns.countplot(df.Principal, hue= df.loan_status, palette='rocket')
plt.title('principal vs loan status')

print('most of the people make a principal choice range from 800 and 1000')
# Out:
# c:\users\amose\appdata\local\programs\python\python39\scripts\opencv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# most of the people make a principal choice range from 800 and 1000

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(df.age, df.past_due_days, hue=df.loan_status,)

print(' most of the peoplethat  paid off thier loan are age between 40 to 50  ')
# Out:
# c:\users\amose\appdata\local\programs\python\python39\scripts\opencv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
#  most of the peoplethat  paid off thier loan are age between 40 to 50

# %%
df.hist(bins=50, figsize=(12,7), color='g' )
# Out:
# array([[<AxesSubplot:title={'center':'Principal'}>,
#         <AxesSubplot:title={'center':'terms'}>],
#        [<AxesSubplot:title={'center':'past_due_days'}>,
#         <AxesSubplot:title={'center':'age'}>]], dtype=object)

# %%
corr=df.corr()
plt.figure(figsize=(12,7))
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
df= df.drop(['Loan_ID','effective_date','due_date','paid_off_time'], axis='columns')
df
# Out:
#             loan_status  Principal  terms  past_due_days  age  \
# 0               PAIDOFF       1000     30          36.01   45
# 1               PAIDOFF       1000     30          36.01   50
# 2               PAIDOFF       1000     30          36.01   33
# 3               PAIDOFF       1000     15          36.01   27
# 4               PAIDOFF       1000     30          36.01   28
# ..                  ...        ...    ...            ...  ...
# 495  COLLECTION_PAIDOFF       1000     30           3.00   28
# 496  COLLECTION_PAIDOFF       1000     15          14.00   26
# 497  COLLECTION_PAIDOFF        800     15           3.00   30
# 498  COLLECTION_PAIDOFF       1000     30           1.00   38
# 499  COLLECTION_PAIDOFF       1000     30           8.00   28
#
#                 education  Gender
# 0    High School or Below    male
# 1                Bechalor  female
# 2                Bechalor  female
# 3                 college    male
# 4                 college  female
# ...

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
df['loan_status']=labelencoder.fit_transform(df['loan_status'])
df['education']=labelencoder.fit_transform(df['education'])
df['Gender']= pd.get_dummies(df['Gender'])
df
# Out:
#      loan_status  Principal  terms  past_due_days  age  education  Gender
# 0              2       1000     30          36.01   45          1       0
# 1              2       1000     30          36.01   50          0       1
# 2              2       1000     30          36.01   33          0       1
# 3              2       1000     15          36.01   27          3       0
# 4              2       1000     30          36.01   28          3       1
# ..           ...        ...    ...            ...  ...        ...     ...
# 495            1       1000     30           3.00   28          1       0
# 496            1       1000     15          14.00   26          1       0
# 497            1        800     15           3.00   30          3       0
# 498            1       1000     30           1.00   38          3       1
# 499            1       1000     30           8.00   28          1       0
#
# [500 rows x 7 columns]

# %%
data=df.drop(labels='loan_status', axis=1)
target=df.loan_status

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data, target, test_size=0.2)

# %%
# %%time
from sklearn.linear_model import LogisticRegression
lr= LogisticRegression()
lr.fit(x_train, y_train)
lr.score(x_test, y_test)
# Out:
# Wall time: 4.18 s
# c:\users\amose\appdata\local\programs\python\python39\scripts\opencv\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.95

# %%
lr_predict=lr.predict(x_test)
from sklearn.metrics import confusion_matrix
cm_lr= confusion_matrix(y_test, lr_predict)
import seaborn as sns
plt.figure(figsize=(12,7))
sns.heatmap(cm_lr, annot= True, Cmap= 'Accent')
plt.xlabel('predicted')
plt.ylabel('Truth')
# Out:
# c:\users\amose\appdata\local\programs\python\python39\scripts\opencv\lib\site-packages\seaborn\matrix.py:298: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   mesh = ax.pcolormesh(self.plot_data, cmap=self.cmap, **kws)
# Text(87.0, 0.5, 'Truth')

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier
rf= RandomForestClassifier()
rf.fit(x_train, y_train)
rf.score(x_test, y_test)
# Out:
# Wall time: 4.58 s
# 0.98

# %%
rf_predict=rf.predict(x_test)
from sklearn.metrics import confusion_matrix
cm_rf= confusion_matrix(y_test, rf_predict)
import seaborn as sns
plt.figure(figsize=(12,7))
sns.heatmap(cm_rf, annot= True, Cmap= 'Accent')
plt.xlabel('predicted')
plt.ylabel('Truth')
# Out:
# c:\users\amose\appdata\local\programs\python\python39\scripts\opencv\lib\site-packages\seaborn\matrix.py:298: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   mesh = ax.pcolormesh(self.plot_data, cmap=self.cmap, **kws)
# Text(87.0, 0.5, 'Truth')

# %%
# %%time
from sklearn.tree import DecisionTreeClassifier
tree=DecisionTreeClassifier()
tree.fit(x_train,y_train)
tree.score(x_test, y_test)
# Out:
# Wall time: 15 ms
# 0.99

# %%
tree_predict=tree.predict(x_test)
from sklearn.metrics import confusion_matrix
cm_tree= confusion_matrix(y_test, tree_predict)
import seaborn as sns
plt.figure(figsize=(12,7))
sns.heatmap(cm_tree, annot= True)
plt.xlabel('predicted')
plt.ylabel('Truth')
# Out:
# Text(87.0, 0.5, 'Truth')

# %%
model_X= ['LogisticRegression', 'Decision Tree', 'Random Forest']
model_Y= [lr.score(x_test,y_test),tree.score(x_test,y_test),rf.score(x_test,y_test)]
plt.figure(figsize=(12,7))
plt.plot(model_X, model_Y, color='green', marker='*', linestyle='dashed')
plt.title('model performance')
plt.xlabel('model')
plt.ylabel('model accuracy')
# Out:
# Text(0, 0.5, 'model accuracy')

# %%
from sklearn.svm import SVC
model_params={
    'svm':{
        'model':SVC(gamma='auto'),
        'params':{
        'C':[1,10,20],
        'kernel':['rbf','linear']
         }
    },
    'random_forest':{
        'model':RandomForestClassifier(),
        'params':{
            'n_estimators':[1,5,10]
        }
    },
    'logistic_regression':{
        'model':LogisticRegression(solver='liblinear',multi_class='auto'),
        'params':{
            'C':[1,5,10]
        }
    },
    'decision_tree':{
        'model':RandomForestClassifier(),
        'params':{
            'criterion':['gini','entropy']
        }
        
    }
        
}

# %%
from sklearn.model_selection import GridSearchCV

scores=[]
for model_name,mp in model_params.items():
    clf= GridSearchCV(mp['model'],mp['params'],cv=3,return_train_score=False)
    clf.fit(data,target)
    scores.append({
        'model':model_name,
        'best_score':clf.best_score_,
        'best_params':clf.best_params_
    })

# %%
df=pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score                   best_params
# 0                  svm    0.973968  {'C': 1, 'kernel': 'linear'}
# 1        random_forest    0.973956          {'n_estimators': 10}
# 2  logistic_regression    0.949968                      {'C': 5}
# 3        decision_tree    0.973968         {'criterion': 'gini'}
